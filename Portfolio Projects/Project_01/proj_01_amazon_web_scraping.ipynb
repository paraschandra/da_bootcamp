# %% [markdown]
# ### Amazon Web Scraping Using Python

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

# Amazon product URL
url = "https://www.amazon.in/DUDEME-Regular-Sleeves-T-Shirt-Programmer/dp/B0BW9P3Y6F/ref=sr_1_12?crid=3Q594AXSITB2A&dib=eyJ2IjoiMSJ9.EO4RxmrLIYlhINjgwyDqhFsGjE92d7XlS5o6Omk0pXCNCZNJW1H7H1khz8rU-4NRX0-LQpwX13czJs0J7kvHFk8AgBVmyXQk0uFEsAMo1R5d74IxQBcPmirEHrnACgK0Yhmv1JsvueqDVAdT4KJYS-tjxAAFloNAX0CoZl0GfjtOxYriqArgH0QneKAmPlQNEAfwqVi-6TNlIDNB89WgtD9KLu2oKb_o4SeP2Z9cHqg1cjBF-7LSmLCV8HHrwNoUXkpn4ysDjzWO-Yk6_9v8UzZl7r3B3n9NH-BxQKajxxHqJ-eBWeuKnaPos8rooRmjvPTWnyklHDAHASJ648B5oVkOi0iMGS0czDge3fXZhUq1SwRoo-MPELvBim0nS0pMnfKq1NANUxembDuHPBtt5HF97soQWQ8438q1B9mTY0I.RoIH_x70Lfe576Rk-8Kf5KXVv2phc1srwr9si04e1oM&dib_tag=se&keywords=Got+Data+Funny+Business+Data+Analyst+T-Shirt&qid=1734941360&sprefix=got+data+funny+business+data+analyst+t-shirt,aps,327&sr=8-12&th=1&psc=1"

# Send GET request
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Extract product title
    title = soup.find("span", {"id": "productTitle"})
    title = title.get_text(strip=True) if title else "Title not found"
    
    # Extract price
    price = soup.find("span", {"class": "a-price-whole"})
    price = price.get_text(strip=True) if price else "Price not found"
    
    # Extract rating
    rating = soup.find("span", {"class": "a-icon-alt"})
    rating = rating.get_text(strip=True) if rating else "Rating not found"
    
    # Print extracted data
    print(f"Title: {title}")
    print(f"Price: {price}")
    print(f"Rating: {rating}")
else:
    print(f"Failed to retrieve the page, status code: {response.status_code}")
# Out:
# Title: DUDEME Men's Google T-Shirt, 100% Cotton T-Shirts for Programmer, Coding, Developer, Software Mens, Round Neck T Shirts for Women, Half Sleeve Tshirt for Men
# Price: 499
# Rating: 5.0 out of 5 stars

# %%
title = title.split(',', 1)[0]
print(title)
print(price)
rating = rating.split(' ', 1)[0]
print(rating)
# Out:
# DUDEME Men's Google T-Shirt
# 499
# 5.0

# %%
today = datetime.date.today()
print(today)
# Out:
# 2024-12-23

# %%
import csv

header = ['Title', 'Price', 'Rating', 'Date']
data = [title, price, rating, today]

with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'D:\VS Code\Data Analysis\da_bootcamp\Portfolio Projects\AmazonWebScraperDataset.csv')

df
# Out:
#                          Title  Price  Rating        Date
# 0  DUDEME Men's Google T-Shirt    499     5.0  2024-12-23

# %%
def check_price():
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
    }

    # Amazon product URL
    url = "https://www.amazon.in/DUDEME-Regular-Sleeves-T-Shirt-Programmer/dp/B0BW9P3Y6F/ref=sr_1_12?crid=3Q594AXSITB2A&dib=eyJ2IjoiMSJ9.EO4RxmrLIYlhINjgwyDqhFsGjE92d7XlS5o6Omk0pXCNCZNJW1H7H1khz8rU-4NRX0-LQpwX13czJs0J7kvHFk8AgBVmyXQk0uFEsAMo1R5d74IxQBcPmirEHrnACgK0Yhmv1JsvueqDVAdT4KJYS-tjxAAFloNAX0CoZl0GfjtOxYriqArgH0QneKAmPlQNEAfwqVi-6TNlIDNB89WgtD9KLu2oKb_o4SeP2Z9cHqg1cjBF-7LSmLCV8HHrwNoUXkpn4ysDjzWO-Yk6_9v8UzZl7r3B3n9NH-BxQKajxxHqJ-eBWeuKnaPos8rooRmjvPTWnyklHDAHASJ648B5oVkOi0iMGS0czDge3fXZhUq1SwRoo-MPELvBim0nS0pMnfKq1NANUxembDuHPBtt5HF97soQWQ8438q1B9mTY0I.RoIH_x70Lfe576Rk-8Kf5KXVv2phc1srwr9si04e1oM&dib_tag=se&keywords=Got+Data+Funny+Business+Data+Analyst+T-Shirt&qid=1734941360&sprefix=got+data+funny+business+data+analyst+t-shirt,aps,327&sr=8-12&th=1&psc=1"

    # Send GET request
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Extract product title
        title = soup.find("span", {"id": "productTitle"})
        title = title.get_text(strip=True) if title else "Title not found"
        
        # Extract price
        price = soup.find("span", {"class": "a-price-whole"})
        price = price.get_text(strip=True) if price else "Price not found"
        
        # Extract rating
        rating = soup.find("span", {"class": "a-icon-alt"})
        rating = rating.get_text(strip=True) if rating else "Rating not found"
        
        # Print extracted data
        print(f"Title: {title}")
        print(f"Price: {price}")
        print(f"Rating: {rating}")
    else:
        print(f"Failed to retrieve the page, status code: {response.status_code}")
    
    today = datetime.date.today()

    header = ['Title', 'Price', 'Rating', 'Date']
    data = [title, price, rating, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
active = 0

while(active < 10):
    active += 1
    check_price()
    time.sleep(2)
# Out:
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found
# Title: Title not found
# Price: Price not found
# Rating: Rating not found

# %%
df = pd.read_csv(r'D:\VS Code\Data Analysis\da_bootcamp\Portfolio Projects\AmazonWebScraperDataset.csv')

df
# Out:
#                                                 Title            Price  \
# 0                         DUDEME Men's Google T-Shirt              499
# 1                                     Title not found  Price not found
# 2                                     Title not found  Price not found
# 3                                     Title not found  Price not found
# 4                                     Title not found  Price not found
# 5                                     Title not found  Price not found
# 6                                     Title not found  Price not found
# 7                                     Title not found  Price not found
# 8                                     Title not found  Price not found
# 9                                     Title not found  Price not found
# 10                                    Title not found  Price not found
# 11                                    Title not found  Price not found
# ...
